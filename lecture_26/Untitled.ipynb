# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(-10, 10, 100)

# %%
y = np.abs(X)

# %%
plt.plot(X, y)

# %%
plt.plot(X, X**2)

# %%
m = np.linspace(-10, 10, 100)

# %%
esq = (m * 15 + 7) ** 2

# %%
plt.plot(m, esq)

# %%
X = np.linspace(-10, 10, 100)

# %%
m, c = 5, 50

# %%
noise = np.random.randint(-10, 10, 100)

# %%
y = m * X + c + noise

# %%
plt.scatter(X, y)

# %%
class LinearRegCustom:
    
    def __init__(self, lr=1, max_steps=10):
        self.lr = lr
        self.max_steps = max_steps
        
    def fit(self, X, y):
        self.coef_ = np.random.random()
        
        for i in range(self.max_steps):
            self.gradient_decend(X, y)
        
    def gradient_decend(self, X, y):
        delta_coef = self.gradient(X, y)
        print(delta_coef)
        self.coef_ += delta_coef
        
    def gradient(self, X, y):
        yp = self.predict(X)
        d_e2m = np.mean((yp -y) * X)
        
        return -d_e2m * self.lr
        
    def predict(self, X):
        return X * self.coef_

# %%
model = LinearRegCustom(lr=.01, max_steps=20)

# %%
model.fit(X, y)
# Out:
# -0.6724478114478117
# -0.44377027287464993
# -0.2928584965772102
# -0.19326688663007793
# -0.12754313057069097
# -0.08416987741365471
# -0.05554645108779905
# -0.03665691721619058
# -0.02419109688341195
# -0.015964494912958833
# -0.010535491592390327
# -0.0069527149902641385
# -0.004588323697278633
# -0.0030279846621770108
# -0.001998265972345746
# -0.0013187209783830781
# -0.0008702670429732961
# -0.0005743176445210907
# -0.00037901097079513877
# -0.0002501217181003255

# %%
model.coef_
# Out:
# 5.023089345116314

# %%
plt.scatter(X, y)
plt.scatter(X, model.predict(X))

# %%
Xa = np.linspace(0, 10, 100)

# %%
plt.figure()
plt.plot(Xa, Xa*20)
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.show()
