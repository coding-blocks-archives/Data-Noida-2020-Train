# %%
import numpy as np
import matplotlib.pyplot as plt
import PIL

# %%
cb_pil = PIL.Image.open("cb.png")

# %%
cb_np = np.array(cb_pil)

# %%
cb_np.shape
# Out:
# (189, 454, 4)

# %%
panda_pil = PIL.Image.open("../lecture_01/panda.jpg")

# %%
panda_np = np.array(panda_pil)

# %%
plt.imshow(cb_np[:, :, 3], cmap="gray")

# %%
cb_np.shape
# Out:
# (189, 454, 4)

# %%
panda_np.shape
# Out:
# (720, 1280, 3)

# %%
w = cb_np.shape[1]
h = cb_np.shape[0]

x = 400
y = 400

# %%
cut = panda_np[y:y+h, x:x+w]

# %%
plt.imshow(cut)

# %%
plt.imshow(panda_np)

# %%
for row in range(cb_np.shape[0]):
    for col in range(cb_np.shape[1]):
        if cb_np[row, col, 3] > 100:
            cut[row, col] = cb_np[row, col, :3]

# %%
plt.imshow(panda_np)

# %%
img = PIL.Image.fromarray(panda_np)

# %%
f = open("panda_logo.jpg", "wb")
img.save(f)
