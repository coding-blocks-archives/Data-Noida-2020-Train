# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.datasets import make_blobs

# %%
X, _ = make_blobs(centers=6, random_state=42)

# %%
plt.scatter(X[:, 0], X[:, 1])

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(6, n_init=1)

model.fit(X)

model.labels_

plt.scatter(X[:, 0], X[:, 1], c=model.labels_)

for center in model.cluster_centers_:
    plt.scatter(center[0], center[1], s=120)

# %%
plt.scatter(X[:, 0], X[:, 1], c=_)

# %%
model.cluster_centers_
# Out:
# array([[-7.14259351,  8.5485667 ],
#        [-0.16755638, -0.26948931]])

# %%
model.labels_
# Out:
# array([5, 5, 3, 1, 1, 2, 0, 0, 0, 3, 3, 2, 1, 0, 0, 4, 5, 5, 2, 4, 4, 2,
#        3, 1, 4, 4, 1, 4, 5, 0, 2, 1, 4, 5, 4, 4, 3, 3, 3, 0, 2, 2, 0, 0,
#        4, 3, 0, 1, 4, 5, 5, 2, 2, 2, 0, 4, 4, 1, 3, 3, 2, 3, 5, 2, 1, 5,
#        5, 5, 1, 5, 4, 2, 1, 2, 1, 4, 0, 1, 4, 1, 5, 2, 1, 0, 1, 3, 4, 3,
#        3, 3, 1, 0, 2, 2, 1, 3, 1, 3, 0, 0], dtype=int32)

# %%
model.cluster_centers_
# Out:
# array([[ 4.53370563,  2.19397024],
#        [-9.29828625,  7.40947631],
#        [-6.84770403, -7.09318466],
#        [-2.81937737,  8.60427975],
#        [ 2.08787409,  4.23565588],
#        [-9.46663012, 10.02682353]])
